# %% [markdown]
# # Pandas Merge Tutorial
#
#
# ### Basic Merge Using a DataFrame Column

# %%
import pandas as pd
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
})
df1
# Out:
#        city  temperature
# 0  new york           21
# 1   chicago           14
# 2   orlando           35

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","orlando"],
    "humidity": [65,68,75],
})
df2
# Out:
#        city  humidity
# 0   chicago        65
# 1  new york        68
# 2   orlando        75

# %%
df3 = pd.merge(df1,df2,on="city")
df3
# Like inner join
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
import pandas as pd
df4 = pd.DataFrame({
    "city": ["chicago","new york","san francisco"],
    "humidity": [65,68,71],
})
df4
# Out:
#             city  humidity
# 0        chicago        65
# 1       new york        68
# 2  san francisco        71

# %%
df5 = pd.merge(df2,df4,on="city")
df5
# Out:
#        city  humidity_x  humidity_y
# 0   chicago          65          65
# 1  new york          68          68

# %%
df5 = pd.merge(df2,df4,on="city",how="outer")
df5
# Out:
#             city  humidity_x  humidity_y
# 0        chicago        65.0        65.0
# 1       new york        68.0        68.0
# 2        orlando        75.0         NaN
# 3  san francisco         NaN        71.0

# %%
df5 = pd.merge(df2,df4,on="city",how="left")
df5

# Left Join
# Out:
#        city  humidity_x  humidity_y
# 0   chicago          65        65.0
# 1  new york          68        68.0
# 2   orlando          75         NaN

# %%
df5 = pd.merge(df2,df4,on="city",how="right")
df5

# Right Join
# Out:
#             city  humidity_x  humidity_y
# 0        chicago        65.0          65
# 1       new york        68.0          68
# 2  san francisco         NaN          71

# %%
df5 = pd.merge(df2,df4,on="city",how="outer", indicator = True)
df5
# Out:
#             city  humidity_x  humidity_y      _merge
# 0        chicago        65.0        65.0        both
# 1       new york        68.0        68.0        both
# 2        orlando        75.0         NaN   left_only
# 3  san francisco         NaN        71.0  right_only

# %% [markdown]
# ## suffixes

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando", "baltimore"],
    "temperature": [21,14,35,38],
    "humidity": [65,68,71, 75]
})
df1
# Out:
#         city  temperature  humidity
# 0   new york           21        65
# 1    chicago           14        68
# 2    orlando           35        71
# 3  baltimore           38        75

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","san diego"],
    "temperature": [21,14,35],
    "humidity": [65,68,71]
})
df2
# Out:
#         city  temperature  humidity
# 0    chicago           21        65
# 1   new york           14        68
# 2  san diego           35        71

# %%
df3= pd.merge(df1,df2,on="city")
df3
# Out:
#        city  temperature_x  humidity_x  temperature_y  humidity_y
# 0  new york             21          65             14          68
# 1   chicago             14          68             21          65

# %%
df3= pd.merge(df1,df2,on="city",how="outer", suffixes=('_first','_second'))
df3
# Out:
#         city  temperature_first  humidity_first  temperature_second  \
# 0   new york               21.0            65.0                14.0
# 1    chicago               14.0            68.0                21.0
# 2    orlando               35.0            71.0                 NaN
# 3  baltimore               38.0            75.0                 NaN
# 4  san diego                NaN             NaN                35.0
#
#    humidity_second
# 0             68.0
# 1             65.0
# 2              NaN
# 3              NaN
# 4             71.0
